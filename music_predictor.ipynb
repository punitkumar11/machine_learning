# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib

music_data = pd.read_csv('music.csv')

print(music_data)
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
music_data.drop(columns=['genre'])

x = music_data.drop(columns=['genre'])
x
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
y = music_data['genre']

y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
#X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

#model = DecisionTreeClassifier()
#model.fit(X_train, y_train)

#joblib.dump(model, 'music_predictor.joblib')

#predictions = model.predict(X_test)

model = joblib.load('music_predictor.joblib')
predictions = model.predict([[21, 1]])

predictions

#score = accuracy_score(y_test, predictions)
#score
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 10
#       1 #X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20)
#       2
#       3 #model = DecisionTreeClassifier()
#    (...)
#       7
#       8 #predictions = model.predict(X_test)
# ---> 10 model = joblib.load('music_predictor.joblib')
#      11 predictions = model.predict([[21, 1]])
#      13 predictions
#
# File /opt/anaconda3/lib/python3.12/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'music_predictor.joblib'

# %%
tree.export_graphviz(model, out_file='music_predictor.joblib',
                     feature_names=['age', 'gender'],
                     class_names=sorted(y.unique()),
                     label = 'all',
                     rounded=True,
                     filled=True,
                     )
